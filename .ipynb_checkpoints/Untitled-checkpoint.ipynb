# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
import json

# %%
CLIENT_ID = "b0373913b273458aad9b8dcae5369da0"
CLIENT_SECRET = "67471ba8593a428594dcafac1ad866d3"

data = {'Sanam Gambhir': '6C70YxzkKJhdL4uND1hCaC', 'spotify': '37i9dQZF1DX5IDTimEWoTd', 'ROYAL NINJA': '2RdquYcoGqFNP1KUGIUOaL', "jp'sjams":'5xEIQ2u3ZzG5gt0Cg7uDrj'}


# Create empty dataframe
playlist_features_list = ["artist","album","track_name",  "track_id","danceability","energy","key","loudness","mode", "speechiness","instrumentalness","liveness","valence","tempo", "duration_ms","time_signature"]  
playlist_df = pd.DataFrame(columns = playlist_features_list)

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# %%
for i in data.keys():
    
    playlist = spotify.user_playlist_tracks(i, data[i])["items"]
    for track in playlist:
        
        # Create empty dict
        playlist_features = {}
        
        # Get metadata
        playlist_features["artist"] = track["track"]["album"]["artists"][0]["name"]
        playlist_features["album"] = track["track"]["album"]["name"]
        playlist_features["track_name"] = track["track"]["name"]
        playlist_features["track_id"] = track["track"]["id"]
        playlist_features["popularity"] = track["track"]["popularity"]
        playlist_features["is_local"] = track["track"]["is_local"]
        playlist_features["duration_ms"] = track["track"]["duration_ms"]

        # Get audio features
        audio_features = spotify.audio_features(playlist_features["track_id"])[0]
        for feature in playlist_features_list[4:]:
            playlist_features[feature] = audio_features[feature]

        # Concat the dfs
        track_df = pd.DataFrame(playlist_features, index = [0])
        playlist_df = pd.concat([playlist_df, track_df], ignore_index = True)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#
# ...

# %%
playlist_df
# Out:
#                    artist                             album  \
# 0                    Korn                 Follow The Leader
# 1                    Korn                            Issues
# 2                    Korn         See You On the Other Side
# 3                    Korn         See You On the Other Side
# 4             Limp Bizkit                 Significant Other
# ..                    ...                               ...
# 95  Red Hot Chili Peppers  Californication (Deluxe Edition)
# 96              Pearl Jam                            Jeremy
# 97           Foo Fighters     There Is Nothing Left To Lose
# 98  Red Hot Chili Peppers  Californication (Deluxe Edition)
# 99              Candlebox                         Candlebox
#
#               track_name                track_id  danceability  energy key  \
# 0       Freak On a Leash  6W21LNLz9Sw7sUSNWMSHRu         0.353   0.898   2
# 1   Falling Away from Me  2F6FfZ4w8z3eJpSxPotVO5         0.468   0.769   4
# ...

# %%
category_list_id = []
categories_ids = spotify.categories()['categories']

# %%
for category_id in categories_ids['items']:
    category_list_id.append(category_id['id'])

# %%
category_list_id[1:]
# Out:
# ['0JQ5DAqbMKFHCxg5H5PtqW',
#  '0JQ5DAqbMKFKSopHMaeIeI',
#  '0JQ5DAqbMKFE33XAyDiPIr',
#  '0JQ5DAqbMKFIdOwkMWR5at',
#  '0JQ5DAqbMKFCWjUTdzaG0e',
#  '0JQ5DAqbMKFCfObibaOZbv',
#  '0JQ5DAqbMKFOOxftoKZxod',
#  '0JQ5DAqbMKFPw634sFwguI',
#  '0JQ5DAqbMKFEC4WFtoNRpw',
#  '0JQ5DAqbMKFImHYGo3eTSg',
#  '0JQ5DAqbMKFOx2X0qlR9iG',
#  '0JQ5DAqbMKFLVaM30PMBm4',
#  '0JQ5DAqbMKFLb2EqgLtpjC',
#  '0JQ5DAqbMKFOTGtSOysEXE',
#  '0JQ5DAqbMKFAEu5QlAkwvV',
#  '0JQ5DAqbMKFAUsdyVjCQuL',
#  '0JQ5DAqbMKFIVNxQgRNSg0',
#  '0JQ5DAqbMKFGvOw3O4nLAf',
#  '0JQ5DAqbMKFEOEBCABAxo9']

# %%
raw_playlist_data = pd.DataFrame(columns = ('Name', 'Id'))

# %%
raw_playlist_data
# Out:
# Empty DataFrame
# Columns: [Name, Id]
# Index: []

# %%
playlists = spotify.category_playlists(category_id = '0JQ5DAqbMKFHCxg5H5PtqW')['playlists']['items']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[207], line 2
#       1 playlists = spotify.category_playlists(category_id = '0JQ5DAqbMKFHCxg5H5PtqW')['playlists']['items']
# ----> 2 print(playlists['name'])
#
# TypeError: list indices must be integers or slices, not str

# %%
for playlist in playlists:
    print(playlist['name'], playlist['id'])
    raw_playlist_data['Name'] = playlist['name']
    raw_playlist_data['Id'] = playlist['id']
# Out:
# Hot Hits Hindi 37i9dQZF1DX0XUfTFmNBRM
# Bollywood Mush 37i9dQZF1DXdpQPPZq3F7n
# All Out 00's Hindi 37i9dQZF1DWZNJXX2UeBij
# 00's Love Hits 37i9dQZF1DWVq1SXCH6uFn
# Bollywood Butter 37i9dQZF1DWXtlo6ENS92N
# New Music Hindi 37i9dQZF1DXd8cOUiye1o2
# All Out 90s Hindi 37i9dQZF1DXa2huSXaKVkW
# Trending Valentine's Hits  37i9dQZF1DX14CbVHtvHRB
# 90s Love Hits 37i9dQZF1DXa6iPZDThhLh
# Sad Hindi Melodies 37i9dQZF1DXdFesNN9TzXT
# Bollywood & Chill 37i9dQZF1DWX76Z8XDsZzF
# New in Dance 37i9dQZF1DX3txqabhtJQF
# Bollywood Dance Music 37i9dQZF1DX8xfQRRX1PDm
# 90s Dance Bollywood 37i9dQZF1DXdcRZAcc2QFU
# Happy Vibes  37i9dQZF1DWTwbZHrJRIgD
# 90s Swagger 37i9dQZF1DWWQ4RVrwACVr
# 1 AM Feels Hindi 37i9dQZF1DWX3SoTqhs2rq
# Latest Love Tunes 37i9dQZF1DWZZMVXluTJ3U
# 80's Love Hits 37i9dQZF1DX3NU3NvyoJUz
# Old is Gold 37i9dQZF1DWYRTlrhMB12D

# %%
raw_playlist_data
# Out:
# Empty DataFrame
# Columns: [Name, Id]
# Index: []
